# %% [markdown]
# # datasets
#
# ### pacote csv built-in

# %%
d = open("files/Brasileirao_Matches.csv")
data = d.read()
rows = data.split('\n') # separando linhas quando encontra \n chamado de endline
print(data)
# Out:
# ,3
# 2021-06-13 16:00:00,"Red Bull Bragantino","SP","Fluminense","RJ",NA,NA,2021,3
# 2021-06-13 18:15:00,"Fortaleza","CE","Sport","PE",NA,NA,2021,3
# 2021-06-13 18:15:00,"Bahia","BA","Internacional","RS",NA,NA,2021,3
# 2021-06-13 20:30:00,"Chapecoense","SC","CearÃ¡","CE",NA,NA,2021,3
# 2021-06-13 20:30:00,"Flamengo","RJ","America","MG",NA,NA,2021,3
# 2021-06-14 20:00:00,"CuiabÃ¡","MT","AtlÃ©tico","GO",NA,NA,2021,3
# NA,"Athletico Paranaense","PR","Flamengo","RJ",NA,NA,2021,4
# 2021-06-16 19:00:00,"SÃ£o Paulo","SP","Chapecoense","SC",NA,NA,2021,4
# 2021-06-16 19:00:00,"Internacional","RS","AtlÃ©tico Mineiro","MG",NA,NA,2021,4
# 2021-06-16 20:30:00,"Corinthians","SP","Red Bull Bragantino","SP",NA,NA,2021,4
# 2021-06-16 21:30:00,"Juventude","RS","Palmeiras","SP",NA,NA,2021,4
# 2021-06-17 16:00:00,"America","MG","CuiabÃ¡","MT",NA,NA,2021,4
# 2021-06-17 19:00:00,"CearÃ¡","CE","Bahia","BA",NA,NA,2021,4
# 2021-06-17 19:00:00,"Fluminense","RJ","Santos","SP",NA,NA,2021,4
# ...
