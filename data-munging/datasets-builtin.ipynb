# %% [markdown]
# # datasets
#
# ### pacote csv built-in

# %%
d = open("files/Brasileirao_Matches.csv")
data = d.read()
# separando linhas quando encontra \n chamado de endline
rows = data.split('\n') 
print(data)

# %%
# divisão em colunas
full_data = []
for row in rows:
    split_row = row.split(",")
    full_data.append(split_row)
print(full_data)

# %%
#contando as linhas
count = 0
for row in full_data:
    count += 1
print(count)

# %%
#contando colunas
count=0
for column in full_data[0]:
    count += 1
print(count)

# %%
import os
arquivo = open(os.path.join('files/arquivo-datasets-builtin.txt'),'w')
texto = "texto testando"
texto += "texto sendo testado"
print(texto)
# Out:
# texto testandotexto sendo testado

# %%
for palavra in texto.split():
    arquivo.write(palavra+' ')
arquivo.close()
arquivo=open('files/arquivo-datasets-builtin.txt','r')
print(arquivo.read())
arquivo.close()
# Out:
# texto testandotexto sendo testado

# %%
# usando 'with' a expressão close() é usada automaticamente
with open('files/arquivo-datasets-builtin.txt','r') as arquivo:
    print(arquivo.read())
# Out:
# texto testandotexto sendo testado

# %%
# 
arquivo = open('files/arquivo-datasets-builtin.txt','r')
print(arquivo.read())
# Out:
# texto testandotexto sendo testado

# %%
print(arquivo.read())

# %%
import csv
with open('files/Brasileirao_Matches.csv','r') as arquivo:
    leitor = csv.reader(arquivo)
    for x in leitor:
        print ('nro colunas:', len(x))
        print(x)
# Out:
# ians', 'SP', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '16']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '16']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '16']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '16']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '16']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'America', 'MG', 'NA', 'NA', '2021', '16']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '16']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'Juventude', 'RS', 'NA', 'NA', '2021', '16']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'Corinthians', 'SP', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'Internacional', 'RS', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'America', 'MG', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'Bahia', 'BA', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '17']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'America', 'MG', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'Corinthians', 'SP', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'Internacional', 'RS', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'Bahia', 'BA', 'NA', 'NA', '2021', '18']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Santos', 'SP', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'Juventude', 'RS', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'America', 'MG', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'Sport', 'PE', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '19']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'Corinthians', 'SP', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Internacional', 'RS', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'America', 'MG', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'Bahia', 'BA', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '20']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'Sport', 'PE', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'Juventude', 'RS', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Santos', 'SP', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'America', 'MG', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '21']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Bahia', 'BA', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'America', 'MG', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'Santos', 'SP', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '22']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'Corinthians', 'SP', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'America', 'MG', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'Sport', 'PE', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'Internacional', 'RS', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'Juventude', 'RS', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '23']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Juventude', 'RS', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Internacional', 'RS', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'America', 'MG', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'Santos', 'SP', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'Bahia', 'BA', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '24']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'America', 'MG', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'Bahia', 'BA', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Corinthians', 'SP', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '25']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Sport', 'PE', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'America', 'MG', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'Santos', 'SP', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'Juventude', 'RS', 'NA', 'NA', '2021', '26']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'Internacional', 'RS', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'Corinthians', 'SP', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'America', 'MG', 'Bahia', 'BA', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Santos', 'SP', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'Juventude', 'RS', 'NA', 'NA', '2021', '27']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Corinthians', 'SP', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'America', 'MG', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'Sport', 'PE', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '28']
# nro colunas: 9
# ['NA', 'America', 'MG', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'Internacional', 'RS', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'Santos', 'SP', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'Bahia', 'BA', 'NA', 'NA', '2021', '29']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'Juventude', 'RS', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'America', 'MG', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'Sport', 'PE', 'NA', 'NA', '2021', '30']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'America', 'MG', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'Corinthians', 'SP', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'Bahia', 'BA', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'Internacional', 'RS', 'NA', 'NA', '2021', '31']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'Santos', 'SP', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'Juventude', 'RS', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Sport', 'PE', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'America', 'MG', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '32']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Internacional', 'RS', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Bahia', 'BA', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'America', 'MG', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'Corinthians', 'SP', 'NA', 'NA', '2021', '33']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'Sport', 'PE', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'Juventude', 'RS', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'Santos', 'SP', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'America', 'MG', 'NA', 'NA', '2021', '34']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'Bahia', 'BA', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'Corinthians', 'SP', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'America', 'MG', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'Internacional', 'RS', 'NA', 'NA', '2021', '35']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'Santos', 'SP', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'Sport', 'PE', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'Juventude', 'RS', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'America', 'MG', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '36']
# nro colunas: 9
# ['NA', 'CuiabÃ¡', 'MT', 'Fortaleza', 'CE', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'Chapecoense', 'SC', 'Sport', 'PE', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'Athletico Paranaense', 'PR', 'Palmeiras', 'SP', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'Bahia', 'BA', 'Fluminense', 'RJ', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'CearÃ¡', 'CE', 'America', 'MG', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'Internacional', 'RS', 'AtlÃ©tico', 'GO', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'AtlÃ©tico Mineiro', 'MG', 'Red Bull Bragantino', 'SP', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'SÃ£o Paulo', 'SP', 'Juventude', 'RS', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'Corinthians', 'SP', 'GrÃªmio', 'RS', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'Flamengo', 'RJ', 'Santos', 'SP', 'NA', 'NA', '2021', '37']
# nro colunas: 9
# ['NA', 'AtlÃ©tico', 'GO', 'Flamengo', 'RJ', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'Juventude', 'RS', 'Corinthians', 'SP', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'Red Bull Bragantino', 'SP', 'Internacional', 'RS', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'Sport', 'PE', 'Athletico Paranaense', 'PR', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'Fortaleza', 'CE', 'Bahia', 'BA', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'GrÃªmio', 'RS', 'AtlÃ©tico Mineiro', 'MG', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'America', 'MG', 'SÃ£o Paulo', 'SP', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'Santos', 'SP', 'CuiabÃ¡', 'MT', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'Palmeiras', 'SP', 'CearÃ¡', 'CE', 'NA', 'NA', '2021', '38']
# nro colunas: 9
# ['NA', 'Fluminense', 'RJ', 'Chapecoense', 'SC', 'NA', 'NA', '2021', '38']
